# %% [markdown]
# ### ScrapeData With the conterbuter  :

# %%
import pandas as pd
import time

# %%
df = pd.read_csv('Repo_in2023_nettoyé.csv')
df
# Out:
#                                 full_name  \
# 0                 sumn2u/learn-javascript
# 1                   rupali-codes/LinksHub
# 2         LondheShubham153/90DaysOfDevOps
# 3         702573N/Obsidian-Tasks-Timeline
# 4                     yacineMTB/scribepod
# ...                                   ...
# 34437                 soupslurpr/BeauTyXT
# 34438          erix-mx/special-bottom-bar
# 34439                bibjaw99/workstation
# 34440                     whalebone7/Hala
# 34441  Dinil-Thilakarathne/50-js-projects
#
#                                                      url  stargazers_count  \
# 0             https://github.com/sumn2u/learn-javascript               622
# 1               https://github.com/rupali-codes/LinksHub               345
# 2      https://github.com/LondheShubham153/90DaysOfDe...               339
# 3      https://github.com/702573N/Obsidian-Tasks-Time...               165
# 4                 https://github.com/yacineMTB/scribepod               147
# ...

# %% [markdown]
# # Add The contrbuit :

# %%
import requests 
import datetime
import json
from requests.adapters import Retry

# %%
# Authenticate with your GitHub credentials:
access_token = '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'

# %%
url = "https://api.github.com/search/repositories"
# Construct the headers with the access token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Accept": "application/vnd.github.v3+json"  # Specify the API version
}

# %%
start_date = datetime.date(2023, 1, 1)
end_date = datetime.date(2023, 5, 31)
delta = datetime.timedelta(days=1)

all_repo = []
page = 1

while True:
    if start_date == end_date:
        break
    while True:
        print(start_date,'=>',page)
        params = {
            "q": f"created:{start_date}",
            "sort": "stars",
            "order": "desc",
            "per_page": 100,
            "page": page
        }
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()['items']
            all_repo.extend([{
                'name':repo['name'],
                'url':repo['html_url'],
                'description':repo['description'],
                'stars':repo['stargazers_count'],
                'created_at':repo['created_at'],
                'forks':repo['forks'],
                'languages_url':repo['languages_url'],
                'description':repo['description'],
                'forks':repo['forks'],
                'open_issues_count':repo['open_issues_count'],
                'owner':repo['owner'],
                'contributors_url' :repo["contributors_url"]
                } for repo in data])
            if "next" in response.links:
                page += 1
            else:
                print(page)
                break
        else:
            print(f"Error: {response.status_code} - {response.text}")
        time.sleep(1)
    if page == 5:
        page = 1
        start_date += delta
    time.sleep(1)
all_repo

# %%
df = pd.DataFrame(all_repo)

# %%
# function to get the contributors names of each repository :

def get_contributors_names(repo_url):
    print('.')
    repo_name = repo_url[19:]
    contributors_names = []
    contributions_count = []
    url = 'https://api.github.com/repos/' + repo_name + '/contributors'
    headers = {'Authorization': 'token ' + access_token}

    # Retry configuration
    retries = Retry(total=5, backoff_factor=0.1, status_forcelist=[500, 502, 503, 504])

    # Create a session with the configured retry strategy
    session = requests.Session()
    session.mount('https://', requests.adapters.HTTPAdapter(max_retries=retries))

    r = session.get(url, headers=headers)
    r.raise_for_status()

    try:
        json_data = json.loads(r.text)
        for i in range(len(json_data)):
            contributors_names.append(json_data[i]['login'])
            contributions_count.append(json_data[i]['contributions'])
        return [{'contributors_names' : contributors_names, 'contributions_count': contributions_count}]
    except requests.exceptions.RequestException as e :
        print('Error: ' + str(e))
        time.sleep(5)
        return r.status_code

# %%
df['contributors'] = df['full_name'].apply(get_contributors_names)

# %%
df.to_csv(f'Repo_in2023_Analytics.csv', index=False)
